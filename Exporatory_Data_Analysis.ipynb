# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:/Users/saad/Desktop/PyProjects/Supplement_Sales_Weekly_Expanded.csv")

# %%
df.head(5)
# Out:
#          Date  Product Name     Category  Units Sold  Price  Revenue  \
# 0  2020-01-06  Whey Protein      Protein         143  31.98  4573.14
# 1  2020-01-06     Vitamin C      Vitamin         139  42.51  5908.89
# 2  2020-01-06      Fish Oil        Omega         161  12.91  2078.51
# 3  2020-01-06  Multivitamin      Vitamin         140  16.07  2249.80
# 4  2020-01-06   Pre-Workout  Performance         157  35.47  5568.79
#
#    Discount  Units Returned Location Platform
# 0      0.03               2   Canada  Walmart
# 1      0.04               0       UK   Amazon
# 2      0.25               0   Canada   Amazon
# 3      0.08               0   Canada  Walmart
# 4      0.25               3   Canada    iHerb

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                       Date   Units Sold        Price       Revenue  \
# count                 4384  4384.000000  4384.000000   4384.000000
# mean   2022-08-18 12:00:00   150.200274    34.781229   5226.569446
# min    2020-01-06 00:00:00   103.000000    10.000000   1284.000000
# 25%    2021-04-26 00:00:00   142.000000    22.597500   3349.372500
# 50%    2022-08-18 12:00:00   150.000000    34.720000   5173.140000
# 75%    2023-12-11 00:00:00   158.000000    46.712500   7009.960000
# max    2025-03-31 00:00:00   194.000000    59.970000  10761.850000
# std                    NaN    12.396099    14.198309   2192.491946
#
#           Discount  Units Returned
# count  4384.000000     4384.000000
# mean      0.124398        1.531478
# min       0.000000        0.000000
# 25%       0.060000        1.000000
# 50%       0.120000        1.000000
# 75%       0.190000        2.000000
# max       0.250000        8.000000
# std       0.071792        1.258479

# %%
df.describe(include="object")
# Out:
#         Product Name Category Location Platform
# count           4384     4384     4384     4384
# unique            16       10        3        3
# top     Whey Protein  Vitamin   Canada    iHerb
# freq             274      822     1507     1499

# %%
daily_sales=df.groupby("Date").agg({
        "Revenue" : "sum",
        "Units Sold" : "sum",
        "Units Returned" : "sum"
    }).reset_index()

# %%
daily_sales
# Out:
#           Date   Revenue  Units Sold  Units Returned
# 0   2020-01-06  71848.56        2406              19
# 1   2020-01-13  72416.18        2374              27
# 2   2020-01-20  76152.42        2370              26
# 3   2020-01-27  70306.73        2397              29
# 4   2020-02-03  98011.64        2384              34
# ..         ...       ...         ...             ...
# 269 2025-03-03  66065.44        2431              36
# 270 2025-03-10  92509.57        2411              30
# 271 2025-03-17  65590.53        2381              22
# 272 2025-03-24  69778.44        2416              27
# 273 2025-03-31  81915.03        2410              20
#
# [274 rows x 4 columns]

# %%
sns.lineplot(x="Date",y="Revenue",data=daily_sales)
plt.title("Daily Revenue Over Time")
plt.xticks(rotation=45)
plt.show()

# %%
category_revenue=df.groupby("Category")["Revenue"].sum().sort_values(ascending=False)

# %%
category_revenue
# Out:
# Category
# Vitamin        4300224.68
# Mineral        4276107.99
# Performance    2909702.18
# Protein        2855492.09
# Amino Acid     1464819.63
# Omega          1451065.87
# Fat Burner     1440900.05
# Hydration      1411951.38
# Herbal         1405700.79
# Sleep Aid      1397315.79
# Name: Revenue, dtype: float64

# %%
sns.barplot(x=category_revenue.index, y=category_revenue.values)
plt.title("Revenue by Product Revenue")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
loc_platform = df.groupby(["Location","Platform"])["Revenue"].sum().unstack().fillna(0)

# %%
loc_platform
# Out:
# Platform      Amazon     Walmart       iHerb
# Location
# Canada    2613844.28  2518639.07  2716096.38
# UK        2442671.23  2637066.25  2624222.86
# USA       2612936.27  2232862.30  2514941.81

# %%
loc_platform.plot(kind="bar" , stacked=True)
plt.title("Revenue by Location ans Platform")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
top_products=df.groupby("Product Name","Location")["Revenue"].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 top_products=df.groupby("Product Name","Location")["Revenue"].sum().sort_values(ascending=False)
#
# File ~\Desktop\PyProjects\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\Desktop\PyProjects\.venv\Lib\site-packages\pandas\core\frame.py:10835, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10831
#   10832         if level is None and by is None:
#   10833             raise TypeError("You have to supply one of 'by' and 'level'")
#   10834
# > 10835         return DataFrameGroupBy(
#   10836             obj=self,
#   10837             keys=by,
#   10838             level=level,
#
# File ~\Desktop\PyProjects\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~\Desktop\PyProjects\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:789, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     787 if isinstance(level, str):
#     788     if obj.index.name != level:
# --> 789         raise ValueError(f"level name {level} is not the name of the index")
#     790 elif level > 0 or level < -1:
#     791     raise ValueError("level > 0 or level < -1 only valid with MultiIndex")
#
# ValueError: level name Location is not the name of the index

# %%
top_products
# Out:
# Product Name
# Biotin               1486798.62
# Zinc                 1482546.95
# Pre-Workout          1477183.78
# BCAA                 1464819.63
# Fish Oil             1451065.87
# Green Tea Extract    1440900.05
# Collagen Peptides    1433297.24
# Creatine             1432518.40
# Iron Supplement      1431582.41
# Whey Protein         1422194.85
# Name: Revenue, dtype: float64

# %%
df
# Out:
#            Date        Product Name     Category  Units Sold  Price  Revenue  \
# 0    2020-01-06        Whey Protein      Protein         143  31.98  4573.14
# 1    2020-01-06           Vitamin C      Vitamin         139  42.51  5908.89
# 2    2020-01-06            Fish Oil        Omega         161  12.91  2078.51
# 3    2020-01-06        Multivitamin      Vitamin         140  16.07  2249.80
# 4    2020-01-06         Pre-Workout  Performance         157  35.47  5568.79
# ...         ...                 ...          ...         ...    ...      ...
# 4379 2025-03-31           Melatonin    Sleep Aid         160  47.79  7646.40
# 4380 2025-03-31              Biotin      Vitamin         154  38.12  5870.48
# 4381 2025-03-31   Green Tea Extract   Fat Burner         139  20.40  2835.60
# 4382 2025-03-31     Iron Supplement      Mineral         154  18.31  2819.74
# 4383 2025-03-31  Electrolyte Powder    Hydration         178  39.12  6963.36
#
#       Discount  Units Returned Location Platform
# 0         0.03               2   Canada  Walmart
# 1         0.04               0       UK   Amazon
# 2         0.25               0   Canada   Amazon
# 3         0.08               0   Canada  Walmart
# 4         0.25               3   Canada    iHerb
# ...        ...             ...      ...      ...
# 4379      0.21               1      USA    iHerb
# 4380      0.22               1       UK  Walmart
# 4381      0.12               3      USA    iHerb
# 4382      0.23               2   Canada   Amazon
# 4383      0.23               0       UK    iHerb
#
# [4384 rows x 10 columns]

# %%
sns.barplot(x=top_products.index, y=top_products.values)
plt.title("Top 10 Products by Revenue")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
df["Return Rate"] = df["Units Returned"] / df["Units Sold"]

# %%
category_return=df.groupby("Category")["Return Rate"].mean().sort_values(ascending=False)

# %%
category_return
# Out:
# Category
# Hydration      0.010746
# Vitamin        0.010475
# Amino Acid     0.010355
# Fat Burner     0.010229
# Performance    0.010207
# Protein        0.010203
# Mineral        0.010079
# Omega          0.009870
# Sleep Aid      0.009860
# Herbal         0.009433
# Name: Return Rate, dtype: float64

# %%
sns.barplot(x=category_return.index, y=category_return.values)
plt.title("Average Return Rate by Category")
plt.ylabel("Return Rate")
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(data=df,x="Discount",y="Revenue",hue="Category",alpha=0.6)
plt.title("Discount vs Revenue")
plt.show()

# %%
corr=df[["Units Sold","Price","Revenue","Discount","Units Returned"]].corr()

# %%
corr
# Out:
#                 Units Sold     Price   Revenue  Discount  Units Returned
# Units Sold        1.000000  0.013749  0.210462 -0.010435        0.116523
# Price             0.013749  1.000000  0.977198 -0.008668       -0.010410
# Revenue           0.210462  0.977198  1.000000 -0.012531        0.012432
# Discount         -0.010435 -0.008668 -0.012531  1.000000        0.004276
# Units Returned    0.116523 -0.010410  0.012432  0.004276        1.000000

# %%
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# %pip install -U ipykernel ipython nbformat
# Out:
# Requirement already satisfied: ipykernel in .\.venv\Lib\site-packages (7.3.0)
# Requirement already satisfied: ipython in .\.venv\Lib\site-packages (9.17.1)
# Requirement already satisfied: nbformat in .\.venv\Lib\site-packages (5.11.1)
# Requirement already satisfied: comm>=0.1.1 in .\.venv\Lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in .\.venv\Lib\site-packages (from ipykernel) (1.8.22)
# Requirement already satisfied: jupyter-client>=8.9.0 in .\.venv\Lib\site-packages (from ipykernel) (8.10.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in .\.venv\Lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in .\.venv\Lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in .\.venv\Lib\site-packages (from ipykernel) (1.7.3)
# Requirement already satisfied: packaging>=22 in .\.venv\Lib\site-packages (from ipykernel) (26.3)
# Requirement already satisfied: psutil>=5.7 in .\.venv\Lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in .\.venv\Lib\site-packages (from ipykernel) (27.2.0)
# Requirement already satisfied: tornado>=6.4.1 in .\.venv\Lib\site-packages (from ipykernel) (6.5.10)
# Requirement already satisfied: traitlets>=5.4.0 in .\.venv\Lib\site-packages (from ipykernel) (5.16.1)
# Requirement already satisfied: colorama>=0.4.4 in .\.venv\Lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\.venv\Lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in .\.venv\Lib\site-packages (from ipython) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\.venv\Lib\site-packages (from ipython) (3.0.53)
# Requirement already satisfied: pygments>=2.14.0 in .\.venv\Lib\site-packages (from ipython) (2.21.0)
# Requirement already satisfied: stack_data>=0.6.0 in .\.venv\Lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in .\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.8.4)
# Requirement already satisfied: fastjsonschema>=2.15 in .\.venv\Lib\site-packages (from nbformat) (2.22.2)
# Requirement already satisfied: jsonschema>=2.6 in .\.venv\Lib\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in .\.venv\Lib\site-packages (from jedi>=0.18.2->ipython) (0.8.7)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat) (2026.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.13.0 in .\.venv\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in .\.venv\Lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.11.12)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython) (3.0.2)
# Requirement already satisfied: pure-eval in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython) (0.2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
fig=px.line(df,x="Date",y="Revenue",color="Category",title="Revenue Over Time")
fig.show(renderer="browser")

# %% [markdown]
# ###   _____________________________________________________________________________________________________

# %%
df["Monthly"]=df["Date"].dt.to_period("M")
monthly=df.groupby("Monthly").agg({
    "Revenue" : "sum",
    "Units Sold" : "sum",
    "Discount" : "mean",
    "Units Returned" : "sum"
}).reset_index()

# %%
monthly
# Out:
#     Monthly    Revenue  Units Sold  Discount  Units Returned
# 0   2020-01  290723.89        9547  0.120313             101
# 1   2020-02  355213.26        9493  0.128125              91
# 2   2020-03  416547.17       12145  0.111375             123
# 3   2020-04  326287.92        9605  0.138281              91
# 4   2020-05  333210.99        9557  0.119375              90
# ..      ...        ...         ...       ...             ...
# 58  2024-11  329894.33        9838  0.117813             106
# 59  2024-12  446728.99       12042  0.127125              99
# 60  2025-01  304965.15        9617  0.125156              92
# 61  2025-02  341768.25        9542  0.128125             103
# 62  2025-03  375859.01       12049  0.124625             135
#
# [63 rows x 5 columns]

# %%
monthly["Monthly"]= monthly["Monthly"].astype(str)

# %%
fig , axes = plt.subplots(2,1,sharex=True,figsize=(16,12))

sns.lineplot(data=monthly,x="Monthly",y="Revenue",ax=axes[0])
axes[0].set_title("Monthly Revenue Trend")
axes[0].tick_params(axis="x",rotation=45)

sns.lineplot(data=monthly,x="Monthly",y="Units Sold",ax=axes[1])
axes[1].set_title("Monthly Unites Sold Trend ")
axes[1].tick_params(axis="x",rotation=45)

plt.tight_layout()
plt.show()

# %%
df["Net Revenue"] = df["Revenue"]  - (df["Units Returned"]*df["Price"])
df.head(10)
# Out:
#         Date       Product Name     Category  Units Sold  Price  Revenue  \
# 0 2020-01-06       Whey Protein      Protein         143  31.98  4573.14
# 1 2020-01-06          Vitamin C      Vitamin         139  42.51  5908.89
# 2 2020-01-06           Fish Oil        Omega         161  12.91  2078.51
# 3 2020-01-06       Multivitamin      Vitamin         140  16.07  2249.80
# 4 2020-01-06        Pre-Workout  Performance         157  35.47  5568.79
# 5 2020-01-06               BCAA   Amino Acid         154  41.19  6343.26
# 6 2020-01-06           Creatine  Performance         134  32.49  4353.66
# 7 2020-01-06               Zinc      Mineral         147  46.68  6861.96
# 8 2020-01-06  Collagen Peptides      Protein         147  10.96  1611.12
# 9 2020-01-06          Magnesium      Mineral         134  20.76  2781.84
#
#    Discount  Units Returned Location Platform  Net Revenue
# 0      0.03               2   Canada  Walmart      4509.18
# 1      0.04               0       UK   Amazon      5908.89
# 2      0.25               0   Canada   Amazon      2078.51
# 3      0.08               0   Canada  Walmart      2249.80
# 4      0.25               3   Canada    iHerb      5462.38
# 5      0.13               1       UK  Walmart      6302.07
# 6      0.05               1       UK  Walmart      4321.17
# 7      0.19               0   Canada   Amazon      6861.96
# 8      0.06               2      USA   Amazon      1589.20
# 9      0.00               0   Canada   Amazon      2781.84

# %%
# Out:
#         Date       Product Name     Category  Units Sold  Price  Revenue  \
# 0 2020-01-06       Whey Protein      Protein         143  31.98  4573.14
# 1 2020-01-06          Vitamin C      Vitamin         139  42.51  5908.89
# 2 2020-01-06           Fish Oil        Omega         161  12.91  2078.51
# 3 2020-01-06       Multivitamin      Vitamin         140  16.07  2249.80
# 4 2020-01-06        Pre-Workout  Performance         157  35.47  5568.79
# 5 2020-01-06               BCAA   Amino Acid         154  41.19  6343.26
# 6 2020-01-06           Creatine  Performance         134  32.49  4353.66
# 7 2020-01-06               Zinc      Mineral         147  46.68  6861.96
# 8 2020-01-06  Collagen Peptides      Protein         147  10.96  1611.12
# 9 2020-01-06          Magnesium      Mineral         134  20.76  2781.84
#
#    Discount  Units Returned Location Platform  Return Rate  Monthly  \
# 0      0.03               2   Canada  Walmart     0.013986  2020-01
# 1      0.04               0       UK   Amazon     0.000000  2020-01
# 2      0.25               0   Canada   Amazon     0.000000  2020-01
# 3      0.08               0   Canada  Walmart     0.000000  2020-01
# 4      0.25               3   Canada    iHerb     0.019108  2020-01
# 5      0.13               1       UK  Walmart     0.006494  2020-01
# 6      0.05               1       UK  Walmart     0.007463  2020-01
# 7      0.19               0   Canada   Amazon     0.000000  2020-01
# 8      0.06               2      USA   Amazon     0.013605  2020-01
# 9      0.00               0   Canada   Amazon     0.000000  2020-01
#
#    Net Revenue
# 0      4509.18
# 1      5908.89
# 2      2078.51
# 3      2249.80
# 4      5462.38
# 5      6302.07
# 6      4321.17
# 7      6861.96
# 8      1589.20
# 9      2781.84

# %%
category_profit=df.groupby("Category")["Net Revenue"].sum().sort_values(ascending=False)

# %%
category_profit
# Out:
# Category
# Vitamin        4255337.22
# Mineral        4233108.50
# Performance    2879997.43
# Protein        2827040.48
# Amino Acid     1449514.18
# Omega          1436916.36
# Fat Burner     1426130.43
# Hydration      1396778.95
# Herbal         1392349.37
# Sleep Aid      1383401.64
# Name: Net Revenue, dtype: float64

# %%
sns.barplot(x=category_profit.index,y=category_profit.values)
plt.title("Net Revenue by Category")
plt.ylabel("Net Revenue")
plt.xticks(rotation=45)
plt.show()
